# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#                          State                  District      Crop     Year  \
# 0  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2001-02
# 1  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2002-03
# 2  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2003-04
# 3  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Arecanut  2001-02
# 4  Andaman and Nicobar Islands            SOUTH ANDAMANS  Arecanut  2002-03
#
#        Season    Area Area Units  Production Production Units     Yield
# 0      Kharif  1254.0    Hectare      2061.0           Tonnes  1.643541
# 1  Whole Year  1258.0    Hectare      2083.0           Tonnes  1.655803
# 2  Whole Year  1261.0    Hectare      1525.0           Tonnes  1.209358
# 3      Kharif  3100.0    Hectare      5239.0           Tonnes  1.690000
# 4  Whole Year  3105.0    Hectare      5267.0           Tonnes  1.696296

# %%
state= data['State'].unique()
print(state)
# Out:
# ['Andaman and Nicobar Islands' 'Andhra Pradesh' 'Arunachal Pradesh'
#  'Assam' 'Bihar' 'Chandigarh' 'Chhattisgarh' 'Dadra and Nagar Haveli'
#  'Daman and Diu' 'Delhi' 'Goa' 'Gujarat' 'Haryana' 'Himachal Pradesh'
#  'Jammu and Kashmir' 'Jharkhand' 'Karnataka' 'Kerala' 'Madhya Pradesh'
#  'Maharashtra' 'Manipur' 'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha'
#  'Puducherry' 'Punjab' 'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Tripura'
#  'Uttar Pradesh' 'Uttarakhand' 'West Bengal' 'Telangana' 'Laddakh']

# %%
#corr area, production, field
requiredColumns = ['Area','Production','Yield']
subset_data = data[requiredColumns]
matrix = subset_data.corr(method='pearson') 
print(matrix)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 #corr area, production, field
#       2 requiredColumns = ['Area','Production','Field']
# ----> 3 subset_data = data[requiredColumns]
#       4 matrix = subset_data.corr(method='pearson')
#       5 print(matrix)
#
# File ~/Documents/work/nonsense/assessment_1/env/lib/python3.13/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/work/nonsense/assessment_1/env/lib/python3.13/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
# ...
